# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'C:\Users\tommy\OneDrive\Documents\Personal homework use\tableau\JC-201909-citibike-tripdata.csv')

# %%
df2 = pd.read_csv(r'C:\Users\tommy\OneDrive\Documents\Personal homework use\tableau\JC-201910-citibike-tripdata.csv')

# %%
df3 = pd.read_csv(r'C:\Users\tommy\OneDrive\Documents\Personal homework use\tableau\JC-201911-citibike-tripdata.csv')

# %%
citibike_2019 = pd.concat([df1, df2, df3])
citibike_2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           145  2019-09-01 00:00:37.6920  2019-09-01 00:03:03.0100
# 1           212  2019-09-01 00:03:00.6000  2019-09-01 00:06:33.3420
# 2           569  2019-09-01 00:07:13.0020  2019-09-01 00:16:42.8610
# 3          1380  2019-09-01 00:07:25.3350  2019-09-01 00:30:26.1640
# 4          1346  2019-09-01 00:07:56.4670  2019-09-01 00:30:22.5440
#
#    start station id start station name  start station latitude  \
# 0              3640     Journal Square               40.733670
# 1              3194    McGinley Square               40.725340
# 2              3214   Essex Light Rail               40.712774
# 3              3214   Essex Light Rail               40.712774
# 4              3214   Essex Light Rail               40.712774
#
#    start station longitude  end station id            end station name  \
# 0               -74.062500            3206                     Hilltop
# ...

# %%
citibike_2019.to_csv(r'C:\Users\tommy\OneDrive\Documents\Personal homework use\tableau\citi_bike2019.csv')
